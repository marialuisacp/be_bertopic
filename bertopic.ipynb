# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bible-04/04_nova_almeida_atualizada.csv

# %%
# %%capture
# !pip install bertopic

# %%
from bertopic import BERTopic

# %%
df = pd.read_csv('/kaggle/input/bible-04/04_nova_almeida_atualizada.csv')

# %%
df.head()
# Out:
#       id  bible  book  chapter  verseId  \
# 0  93315      4     1        1        1
# 1  93316      4     1        1        2
# 2  93317      4     1        1        3
# 3  93318      4     1        1        4
# 4  93319      4     1        1        5
#
#                                            verseText
# 0        No princípio, Deus criou os céus e a terra.
# 1  A terra era sem forma e vazia; havia trevas so...
# 2       Então Deus disse:  -  Haja luz! E houve luz.
# 3  E Deus viu que a luz era boa e fez separação e...
# 4  Deus chamou à luz ´dia` e chamou às trevas ´no...

# %%
docs = df['verseText'].tolist()

# %%
docs[0]
# Out:
# 'No princípio, Deus criou os céus e a terra.'

# %%
topic_model = BERTopic(language="portuguese", calculate_probabilities=True, verbose=True)

# %%
topics, probs = topic_model.fit_transform(docs)
# Out:
# Downloading (…)0fe39/.gitattributes:   0%|          | 0.00/968 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)83e900fe39/README.md:   0%|          | 0.00/3.79k [00:00<?, ?B/s]
# Downloading (…)e900fe39/config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/471M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading unigram.json:   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# Downloading (…)900fe39/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Batches:   0%|          | 0/973 [00:00<?, ?it/s]
# 2023-05-24 08:25:01,246 - BERTopic - Transformed documents to Embeddings
# 2023-05-24 08:25:54,476 - BERTopic - Reduced dimensionality
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2023-05-24 08:30:44,695 - BERTopic - Clustered reduced embeddings

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                        Name
# 0       -1  16041                          -1_que_não_os_deus
# 1        0    936       0_jesus_discípulos_respondeu_fariseus
# 2        1    521                1_filho_filhos_família_foram
# 3        2    415                 2_egito_faraó_egípcios_josé
# 4        3    392         3_oferta_altar_holocausto_sacerdote
# ..     ...    ...                                         ...
# 315    314     10            314_décima_oitava_vingado_sétima
# 316    315     10  315_tenham_sobrecarregado_orgia_afadigamos
# 317    316     10     316_imaginem_castigadas_cairá_esconderá
# 318    317     10                 317_aberta_batam_dado_peçam
# 319    318     10         318_beber_cálice_contaminar_pedindo
#
# [320 rows x 3 columns]

# %%
topic_model.get_topic(0)
# Out:
# [('jesus', 0.03875583242744723),
#  ('discípulos', 0.020962158005829713),
#  ('respondeu', 0.009066079249596834),
#  ('fariseus', 0.0083681310311247),
#  ('pedro', 0.008030381180426201),
#  ('lhes', 0.00783780929357003),
#  ('galileia', 0.007422151067102744),
#  ('disse', 0.007191751147433453),
#  ('apóstolos', 0.00711111366688873),
#  ('multidão', 0.0070051166069340426)]

# %%
topic_model.visualize_barchart()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="af1a8ab8-f808-4522-a5e9-161f8a235f49" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("af1a8ab8-f808-4522-a5e9-161f8a235f49")) {                    Plotly.newPlot(                        "af1a8ab8-f808-4522-a5e9-161f8a235f49",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.008030381180426201,0.0083681310311247,0.009066079249596834,0.020962158005829713,0.03875583242744723],"y":["pedro  ","fariseus  ","respondeu  ","discípulos  ","jesus  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.015287306282541125,0.01778663062980729,0.020765787522271664,0.028987559907964047,0.04049833004420001],"y":["chefe  ","foram  ","família  ","filhos  ","filho  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.010732033766641967,0.011458562041404692,0.018298865969298483,0.027663512853301365,0.047115073306183135],"y":["terra  ","josé  ","egípcios  ","faraó  ","egito  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.0183929094006774,0.020227250555579272,0.02099009939618316,0.03074624071657865,0.032728040003929974],"y":["sangue  ","sacerdote  ","holocausto  ","altar  ","oferta  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.01096926482571361,0.013586742440014666,0.01461045380017519,0.015478035073368505,0.07004448777175357],"y":["disse  ","tenda  ","ordenado  ","arão  ","moisés  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.007017793548220493,0.0072270533881161145,0.007526285322595723,0.009974656184642296,0.05391573700846569],"y":["reto  ","gade  ","servo  ","filisteus  ","davi  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.010943087821357908,0.01906219502218218,0.020040807650861064,0.024259684920715237,0.08746069097253481],"y":["mical  ","jônatas  ","samuel  ","davi  ","saul  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.015761201251360657,0.01628813258254788,0.01680979842981531,0.03161447517417302,0.07181320504925709],"y":["paulo  ","judeu  ","sinagogas  ","sinagoga  ","judeus  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"] ...

# %%
topic_model.visualize_topics()
